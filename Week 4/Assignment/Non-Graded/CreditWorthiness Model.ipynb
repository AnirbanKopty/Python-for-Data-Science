# %%
import pandas as pd
import numpy as np
import seaborn as sb

import os

# %%
os.chdir("D:\\Study\\Courses\\NPTEL\\Python for Data Science\\Week 4\\Assignment\\Non-Graded")

crd = pd.read_excel("CreditWorthiness.xlsx", sheet_name= "Data")

# %%
credit = crd.copy()

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Cbal         1000 non-null   object
#  1   Cdur         1000 non-null   int64
#  2   Chist        1000 non-null   object
#  3   Cpur         1000 non-null   object
#  4   Camt         1000 non-null   int64
#  5   Sbal         1000 non-null   object
#  6   Edur         1000 non-null   object
#  7   InRate       1000 non-null   int64
#  8   MSG          1000 non-null   object
#  9   Oparties     1000 non-null   object
#  10  Rdur         1000 non-null   object
#  11  Prop         1000 non-null   object
#  12  age          1000 non-null   int64
#  13  inPlans      1000 non-null   object
#  14  Htype        1000 non-null   object
#  15  NumCred      1000 non-null   int64
#  16  JobType      1000 non-null   object
#  17  Ndepend      1000 non-null   int64
# ...

# %% [markdown]
# - No null values

# %% [markdown]
# # Correlation

# %%
# linear correlated features
sb.heatmap(credit.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# - Cdur, InRate = 0.075
# - Age, Camt = 0.033
# - Cdur, Camt = 0.62
# - Camt, Ndepend = 0.017

# %% [markdown]
# # Avg of Loan Amount for purpose Education

# %%
np.unique(credit.Cpur)
# Out:
# array(['Business', 'domestic needs', 'education', 'electronics',
#        'furniture', 'miscellaneous', 'new vehicle', 'renovation',
#        'retaining', 'second hand vehicle'], dtype=object)

# %%
credit.Cpur.describe()
# Out:
# count            1000
# unique             10
# top       electronics
# freq              280
# Name: Cpur, dtype: object

# %%
credit.Camt.describe()
# Out:
# count      1000.00000
# mean      32592.58000
# std       28227.36876
# min        2380.00000
# 25%       13535.00000
# 50%       23075.00000
# 75%       39602.50000
# max      184120.00000
# Name: Camt, dtype: float64

# %%
sb.boxplot(x=credit.Camt, y=credit.Cpur)
# Out:
# <AxesSubplot:xlabel='Camt', ylabel='Cpur'>

# %%
pd.crosstab(credit.Cpur, 'count')
# Out:
# col_0                count
# Cpur
# Business                97
# domestic needs          12
# education               50
# electronics            280
# furniture              181
# miscellaneous           12
# new vehicle            103
# renovation              22
# retaining                9
# second hand vehicle    234
